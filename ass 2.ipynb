# %%
import pandas as pd

# %%
df=pd.read_csv("Downloads/Academic_Performance - Academic_Performance.csv")

# %%
df.shape
# Out:
# (12411, 13)

# %%
df.isnull()
# Out:
#        STUDENT_ID  GENDER  PLACEMENT  HONOR_OPTED_OR_NOT  EDUCATION_TYPE  \
# 0           False   False      False               False           False
# 1           False   False      False               False           False
# 2           False   False      False               False           False
# 3           False   False      False               False           False
# 4           False   False      False               False           False
# ...           ...     ...        ...                 ...             ...
# 12406       False   False      False               False           False
# 12407       False   False      False               False           False
# 12408       False   False      False               False           False
# 12409       False   False      False               False           False
# 12410       False   False      False               False           False
#
#        ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  COURSE 3 MARKS  \
# ...

# %%
missing_values=df.isnull().sum()

# %%
print(missing_values)
# Out:
# STUDENT_ID             0
# GENDER                22
# PLACEMENT             15
# HONOR_OPTED_OR_NOT    14
# EDUCATION_TYPE        15
# ACADEMIC_PROGRAM      34
# COURSE 1 MARKS        11
# COURSE 2 MARKS         8
# COURSE 3 MARKS        14
# COURSE 4 MARKS        14
# COURSE 5 MARKS        22
# PERCENTILE             0
# OVEARLL_GRADE          0
# dtype: int64

# %%
misvalue_percent = 100 *df.isnull().sum()  / len(df)
print(misvalue_percent)
# Out:
# STUDENT_ID            0.000000
# GENDER                0.177262
# PLACEMENT             0.120861
# HONOR_OPTED_OR_NOT    0.112803
# EDUCATION_TYPE        0.120861
# ACADEMIC_PROGRAM      0.273951
# COURSE 1 MARKS        0.088631
# COURSE 2 MARKS        0.064459
# COURSE 3 MARKS        0.112803
# COURSE 4 MARKS        0.112803
# COURSE 5 MARKS        0.177262
# PERCENTILE            0.000000
# OVEARLL_GRADE         0.000000
# dtype: float64

# %%
# !pip install missingno

# %%
import missingno as msno
msno.bar(df)
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        COURSE 1 MARKS  COURSE 2 MARKS  COURSE 3 MARKS  COURSE 4 MARKS  \
# count    12400.000000    12403.000000    12397.000000    12397.000000
# mean        77.385887       62.191728       59.189562       67.501815
# std         22.716227       27.669357       29.002446       25.505280
# min         -1.000000        1.000000        1.000000        1.000000
# 25%         65.000000       42.000000       36.000000       51.000000
# 50%         85.000000       67.000000       65.000000       74.000000
# 75%         96.000000       86.000000       85.000000       88.000000
# max        100.000000      100.000000      122.000000      111.000000
#
#        COURSE 5 MARKS    PERCENTILE
# count    12389.000000  12411.000000
# mean        53.690532     68.446459
# std         30.007993     25.867550
# min          0.000000      1.000000
# 25%         28.000000     51.000000
# 50%         56.000000     75.000000
# 75%         80.000000     90.000000
# max        107.000000    100.000000

# %%
import numpy as np
df['COURSE 5 MARKS']=df['COURSE 5 MARKS'].replace(np.NaN,df['COURSE 5 MARKS'].mean())
df['COURSE 1 MARKS']=df['COURSE 1 MARKS'].replace(np.NaN,df['COURSE 1 MARKS'].mean())

# %%
missing_values=df.isnull().sum()
print(missing_values)
# Out:
# STUDENT_ID             0
# GENDER                22
# PLACEMENT             15
# HONOR_OPTED_OR_NOT    14
# EDUCATION_TYPE        15
# ACADEMIC_PROGRAM      34
# COURSE 1 MARKS         0
# COURSE 2 MARKS         8
# COURSE 3 MARKS        14
# COURSE 4 MARKS        14
# COURSE 5 MARKS         0
# PERCENTILE             0
# OVEARLL_GRADE          0
# dtype: int64

# %%
df['COURSE 2 MARKS'].isnull().sum()
# Out:
# 8

# %%
df['COURSE 2 MARKS'] = df['COURSE 2 MARKS'].fillna(0)
df['COURSE 2 MARKS'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# 12408  SB11201420578809      M       Yes                 No       ACADEMIC
# 12409  SB11201420578812      F       Yes                Yes       ACADEMIC
# 12410  SB11201420583232      M        No                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM  COURSE 1 MARKS  COURSE 2 MARKS  \
# ...

# %%
df.isnull().sum()
# Out:
# STUDENT_ID             0
# GENDER                22
# PLACEMENT             15
# HONOR_OPTED_OR_NOT    14
# EDUCATION_TYPE        15
# ACADEMIC_PROGRAM      34
# COURSE 1 MARKS         0
# COURSE 2 MARKS         0
# COURSE 3 MARKS        14
# COURSE 4 MARKS        14
# COURSE 5 MARKS         0
# PERCENTILE             0
# OVEARLL_GRADE          0
# dtype: int64

# %%
df['COURSE 3 MARKS']=df['COURSE 3 MARKS'].fillna(10)
df['COURSE 4 MARKS']=df['COURSE 4 MARKS'].fillna(20)

# %%
df.isnull().sum()
# Out:
# STUDENT_ID             0
# GENDER                22
# PLACEMENT             15
# HONOR_OPTED_OR_NOT    14
# EDUCATION_TYPE        15
# ACADEMIC_PROGRAM      34
# COURSE 1 MARKS         0
# COURSE 2 MARKS         0
# COURSE 3 MARKS         0
# COURSE 4 MARKS         0
# COURSE 5 MARKS         0
# PERCENTILE             0
# OVEARLL_GRADE          0
# dtype: int64

# %%
import numpy as np

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')
imputer.fit_transform(df)
# Out:
# array([['SB11201210000129', 'F', 'Yes', ..., 79.0, 91, 'FIRST CLASS'],
#        ['SB11201210000137', 'F', 'Yes', ..., 78.0, 92, 'THIRD CLASS'],
#        ['SB11201210005154', 'M', 'No', ..., 22.0, 7, 'DISTINCTION'],
#        ...,
#        ['SB11201420578809', 'M', 'Yes', ..., 87.0, 95, 'FIRST CLASS'],
#        ['SB11201420578812', 'F', 'Yes', ..., 42.0, 50, 'FIRST CLASS'],
#        ['SB11201420583232', 'M', 'No', ..., 47.0, 89, 'THIRD CLASS']],
#       dtype=object)

# %%
imputer = SimpleImputer(strategy='constant', fill_value='missing')
imputer.fit_transform(df)
# Out:
# array([['SB11201210000129', 'F', 'Yes', ..., 79.0, 91, 'FIRST CLASS'],
#        ['SB11201210000137', 'F', 'Yes', ..., 78.0, 92, 'THIRD CLASS'],
#        ['SB11201210005154', 'M', 'No', ..., 22.0, 7, 'DISTINCTION'],
#        ...,
#        ['SB11201420578809', 'M', 'Yes', ..., 87.0, 95, 'FIRST CLASS'],
#        ['SB11201420578812', 'F', 'Yes', ..., 42.0, 50, 'FIRST CLASS'],
#        ['SB11201420583232', 'M', 'No', ..., 47.0, 89, 'THIRD CLASS']],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# STUDENT_ID             0
# GENDER                22
# PLACEMENT             15
# HONOR_OPTED_OR_NOT    14
# EDUCATION_TYPE        15
# ACADEMIC_PROGRAM      34
# COURSE 1 MARKS         0
# COURSE 2 MARKS         0
# COURSE 3 MARKS         0
# COURSE 4 MARKS         0
# COURSE 5 MARKS         0
# PERCENTILE             0
# OVEARLL_GRADE          0
# dtype: int64

# %%
imputer = SimpleImputer(strategy='constant', fill_value='missing')
imputer.fit_transform(df)
# Out:
# array([['SB11201210000129', 'F', 'Yes', ..., 79.0, 91, 'FIRST CLASS'],
#        ['SB11201210000137', 'F', 'Yes', ..., 78.0, 92, 'THIRD CLASS'],
#        ['SB11201210005154', 'M', 'No', ..., 22.0, 7, 'DISTINCTION'],
#        ...,
#        ['SB11201420578809', 'M', 'Yes', ..., 87.0, 95, 'FIRST CLASS'],
#        ['SB11201420578812', 'F', 'Yes', ..., 42.0, 50, 'FIRST CLASS'],
#        ['SB11201420583232', 'M', 'No', ..., 47.0, 89, 'THIRD CLASS']],
#       dtype=object)

# %%
imputer = SimpleImputer(strategy='most_frequent')
df.ACADEMIC_PROGRAM = imputer.fit_transform(df['ACADEMIC_PROGRAM'].values.reshape([-1,1]))[:,0]

# %%
df.isnull().sum()
# Out:
# STUDENT_ID             0
# GENDER                22
# PLACEMENT             15
# HONOR_OPTED_OR_NOT    14
# EDUCATION_TYPE        15
# ACADEMIC_PROGRAM       0
# COURSE 1 MARKS         0
# COURSE 2 MARKS         0
# COURSE 3 MARKS         0
# COURSE 4 MARKS         0
# COURSE 5 MARKS         0
# PERCENTILE             0
# OVEARLL_GRADE          0
# dtype: int64

# %%
imputer = SimpleImputer(strategy='constant',fill_value='missing')
df.GENDER = imputer.fit_transform(df['GENDER'].values.reshape([-1,1]))[:,0]

imputer = SimpleImputer(strategy='constant',fill_value='missing')
df.PLACEMENT = imputer.fit_transform(df['PLACEMENT'].values.reshape([-1,1]))[:,0]

imputer = SimpleImputer(strategy='constant',fill_value='missing')
df.EDUCATION_TYPE = imputer.fit_transform(df['EDUCATION_TYPE'].values.reshape([-1,1]))[:,0]

imputer = SimpleImputer(strategy='constant',fill_value='missing')
df.HONOR_OPTED_OR_NOT = imputer.fit_transform(df['HONOR_OPTED_OR_NOT'].values.reshape([-1,1]))[:,0]

# %%
df.isnull().sum()
# Out:
# STUDENT_ID            0
# GENDER                0
# PLACEMENT             0
# HONOR_OPTED_OR_NOT    0
# EDUCATION_TYPE        0
# ACADEMIC_PROGRAM      0
# COURSE 1 MARKS        0
# COURSE 2 MARKS        0
# COURSE 3 MARKS        0
# COURSE 4 MARKS        0
# COURSE 5 MARKS        0
# PERCENTILE            0
# OVEARLL_GRADE         0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(data=df['COURSE 1 MARKS'],x=df['COURSE 1 MARKS'])
# Out:
# <AxesSubplot:xlabel='COURSE 1 MARKS'>

# %%
import seaborn as sns
sns.boxplot(data=df['COURSE 2 MARKS'],x=df['COURSE 2 MARKS'])
# Out:
# <AxesSubplot:xlabel='COURSE 2 MARKS'>

# %%
import seaborn as sns
sns.boxplot(data=df['COURSE 3 MARKS'],x=df['COURSE 3 MARKS'])
# Out:
# <AxesSubplot:xlabel='COURSE 3 MARKS'>

# %%
import numpy as np
outliers = []
def detect_outliers_zscore(data):
    thres = 3
    mean = np.mean(data)
    std = np.std(data)
    # print(mean, std)
    for i in data:
        z_score = (i-mean)/std
        if (np.abs(z_score) > thres):
            outliers.append(i)
    return outliers
marks_outliers = detect_outliers_zscore(df['COURSE 1 MARKS'])
print("Outliers from Z-scores method: ", marks_outliers)
# Out:
# Outliers from Z-scores method:  [4.0, 6.0, 3.0, 1.0, 5.0, 2.0, 8.0, 7.0, 2.0, 8.0, 6.0, 9.0, 2.0, 9.0, 8.0, 1.0, 9.0, 2.0, 2.0, 1.0, 6.0, 7.0, 4.0, 5.0, 9.0, 7.0, 9.0, 1.0, 2.0, 8.0, 5.0, 2.0, 8.0, 8.0, 1.0, 4.0, 7.0, 4.0, 7.0, 8.0, 3.0, 8.0, 5.0, 9.0, 7.0, 8.0, 7.0, 1.0, 9.0, 2.0, 7.0, 5.0, 3.0, 7.0, 3.0, 8.0, 6.0, 9.0, 8.0, 9.0, 6.0, 1.0, 7.0, 8.0, 1.0, 9.0, 1.0, 7.0, 8.0, 9.0, 6.0, 7.0, 7.0, 8.0, 4.0, 6.0, 6.0, 5.0, -1.0, 8.0, 8.0, 3.0, 1.0, 3.0, 3.0, 2.0, 9.0, 8.0, 3.0, 6.0, 3.0, 2.0, 7.0, 8.0, 4.0, 8.0, 3.0, 7.0, 9.0, 9.0, 3.0, 7.0, 6.0, 1.0, 1.0, 1.0, -1.0, 9.0, 4.0, 8.0, 7.0, 1.0, 6.0]

# %%
performance_cat = df.select_dtypes(exclude=[np.number])
performance_cat
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F       Yes                Yes       ACADEMIC
# 1      SB11201210000137      F       Yes                Yes       ACADEMIC
# 2      SB11201210005154      M        No                Yes       ACADEMIC
# 3      SB11201210007504      F       Yes                Yes       ACADEMIC
# 4      SB11201210007548      M       Yes                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M       Yes                Yes       ACADEMIC
# 12407  SB11201420573045      M       Yes                Yes       ACADEMIC
# 12408  SB11201420578809      M       Yes                 No       ACADEMIC
# 12409  SB11201420578812      F       Yes                Yes       ACADEMIC
# 12410  SB11201420583232      M        No                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM OVEARLL_GRADE
# ...

# %%
performance_cat.PLACEMENT.replace({"Yes":1,"No": '#'},inplace = True)
performance_cat
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      F         1                Yes       ACADEMIC
# 1      SB11201210000137      F         1                Yes       ACADEMIC
# 2      SB11201210005154      M         #                Yes       ACADEMIC
# 3      SB11201210007504      F         1                Yes       ACADEMIC
# 4      SB11201210007548      M         1                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      M         1                Yes       ACADEMIC
# 12407  SB11201420573045      M         1                Yes       ACADEMIC
# 12408  SB11201420578809      M         1                 No       ACADEMIC
# 12409  SB11201420578812      F         1                Yes       ACADEMIC
# 12410  SB11201420583232      M         #                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM OVEARLL_GRADE
# ...

# %%
performance_cat.GENDER.replace({"M":'-',"F":'+'},inplace = True)
performance_cat
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      +         1                Yes       ACADEMIC
# 1      SB11201210000137      +         1                Yes       ACADEMIC
# 2      SB11201210005154      -         #                Yes       ACADEMIC
# 3      SB11201210007504      +         1                Yes       ACADEMIC
# 4      SB11201210007548      -         1                Yes       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      -         1                Yes       ACADEMIC
# 12407  SB11201420573045      -         1                Yes       ACADEMIC
# 12408  SB11201420578809      -         1                 No       ACADEMIC
# 12409  SB11201420578812      +         1                Yes       ACADEMIC
# 12410  SB11201420583232      -         #                 No       ACADEMIC
#
#                ACADEMIC_PROGRAM OVEARLL_GRADE
# ...

# %%
performance_cat.HONOR_OPTED_OR_NOT.replace({"Yes":1,"No": 0},inplace = True)
performance_cat
# Out:
#              STUDENT_ID GENDER PLACEMENT HONOR_OPTED_OR_NOT EDUCATION_TYPE  \
# 0      SB11201210000129      +         1                  1       ACADEMIC
# 1      SB11201210000137      +         1                  1       ACADEMIC
# 2      SB11201210005154      -         #                  1       ACADEMIC
# 3      SB11201210007504      +         1                  1       ACADEMIC
# 4      SB11201210007548      -         1                  1       ACADEMIC
# ...                 ...    ...       ...                ...            ...
# 12406  SB11201420568705      -         1                  1       ACADEMIC
# 12407  SB11201420573045      -         1                  1       ACADEMIC
# 12408  SB11201420578809      -         1                  0       ACADEMIC
# 12409  SB11201420578812      +         1                  1       ACADEMIC
# 12410  SB11201420583232      -         #                  0       ACADEMIC
#
#                ACADEMIC_PROGRAM OVEARLL_GRADE
# ...
